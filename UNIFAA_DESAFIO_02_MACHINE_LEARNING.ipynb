# %% [markdown]
# <a href="https://colab.research.google.com/github/bgarbero/UNIFAA-DESAFIO-02-MACHINE-LEARNING/blob/main/UNIFAA_DESAFIO_02_MACHINE_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.preprocessing import LabelEncoder

# %%
base_dados = pd.read_csv('/content/drive/MyDrive/insurance.csv', encoding = 'utf-8')

# %%
base_dados = base_dados.drop(1)
base_dados
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
categorical_cols = ['sex', 'children', 'region']

# %%
for col in categorical_cols:
    encoder = LabelEncoder()
    base_dados[col] = encoder.fit_transform(base_dados[col])

# %%
dados = base_dados.drop(columns=['smoker'])
alvo = base_dados['smoker']

# %%
x_train, x_test, y_train, y_test = train_test_split(dados, alvo, test_size=0.20, random_state=42)

# %%
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - Accuracy: 0.4976 - loss: 106.2401
# Epoch 2/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.5004 - loss: 28.0355
# Epoch 3/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.5671 - loss: 23.3295
# Epoch 4/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.5441 - loss: 22.3802
# Epoch 5/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.7913 - loss: 5.9258
# Epoch 6/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.7117 - loss: 7.6308
# Epoch 7/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.6479 - loss: 32.1315
# Epoch 8/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.7587 - loss: 6.6674
# Epoch 9/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8258 - loss: 6.5415
# Epoch 10/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.7618 - loss: 14.9759
# Epoch 11/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.5961 - loss: 27.3323
# Epoch 12/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.7008 - loss: 22.2800
# Epoch 13/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8613 - loss: 5.3449
# Epoch 14/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8002 - loss: 7.7053
# Epoch 15/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8758 - loss: 3.9363
# Epoch 16/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8958 - loss: 2.0740
# Epoch 17/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8668 - loss: 5.6366
# Epoch 18/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.7006 - loss: 21.2952
# Epoch 19/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.7729 - loss: 21.2841
# Epoch 20/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9062 - loss: 2.1111
# Epoch 21/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9034 - loss: 2.6017
# Epoch 22/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8608 - loss: 5.7116
# Epoch 23/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8622 - loss: 4.7403
# Epoch 24/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8933 - loss: 4.9542
# Epoch 25/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.7625 - loss: 15.0449
# Epoch 26/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.9141 - loss: 3.9526
# Epoch 27/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8647 - loss: 6.6994
# Epoch 28/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9102 - loss: 2.9217
# Epoch 29/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8182 - loss: 11.6616
# Epoch 30/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.7993 - loss: 11.8101
# Epoch 31/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8705 - loss: 7.8152
# Epoch 32/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.7919 - loss: 21.9019
# Epoch 33/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8209 - loss: 11.2185
# Epoch 34/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9005 - loss: 4.5316
# Epoch 35/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9039 - loss: 4.8149
# Epoch 36/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9047 - loss: 3.2760
# Epoch 37/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9248 - loss: 1.2719
# Epoch 38/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8929 - loss: 5.3962
# Epoch 39/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8938 - loss: 3.2595
# Epoch 40/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8167 - loss: 11.3834
# Epoch 41/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8856 - loss: 4.9216
# Epoch 42/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8958 - loss: 7.3771
# Epoch 43/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9036 - loss: 6.6126
# Epoch 44/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9019 - loss: 3.0417
# Epoch 45/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8990 - loss: 5.2093
# Epoch 46/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9173 - loss: 3.1845
# Epoch 47/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9019 - loss: 3.9164
# Epoch 48/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8359 - loss: 11.5592
# Epoch 49/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9136 - loss: 4.3481
# Epoch 50/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8514 - loss: 9.7787

# %%
model.evaluate(x_test, y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.9024 - loss: 1.2625
# [1.2828611135482788, 0.9029850959777832]

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# Faz previsões no conjunto de teste.
previsoes_prob = model.predict(x_test)

# Converte as probabilidades previstas em rótulos de classe.
previsoes = np.argmax(previsoes_prob, axis=1)

# Calcula a matriz de confusão.
matrix = confusion_matrix(y_test, previsoes)

print(matrix)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# [[208   4]
#  [ 22  34]]
