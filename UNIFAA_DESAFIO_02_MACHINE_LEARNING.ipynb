# %% [markdown]
# <a href="https://colab.research.google.com/github/bgarbero/UNIFAA-DESAFIO-02-MACHINE-LEARNING/blob/main/UNIFAA_DESAFIO_02_MACHINE_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from google.colab import drive
# Monta o Google Drive no Colab para acessar arquivos.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Carrega o conjunto de dados de seguros a partir do Google Drive.
base_dados = pd.read_csv('/content/drive/MyDrive/insurance.csv', encoding = 'utf-8')
# Remove a primeira linha dos dados (pode estar removendo um cabeçalho duplicado ou uma entrada incorreta).
base_dados = base_dados.drop(1)
# Exibe o DataFrame para verificar se os dados foram carregados corretamente.
base_dados
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
# Separa as características (dados) da coluna de alvo (a ser prevista), que é 'smoker'.
dados = base_dados.drop(columns=['smoker'])
alvo = base_dados['smoker']

# Lista de colunas categóricas que precisam ser codificadas numericamente.
categorical_cols = ['sex', 'children', 'region']

# Converte as colunas categóricas em valores numéricos usando LabelEncoder.
for col in categorical_cols:
    le = LabelEncoder()
    dados[col] = le.fit_transform(dados[col])

# Converte a variável alvo 'smoker' em valores numéricos usando LabelEncoder.
for col in categorical_cols:
    le = LabelEncoder()
    alvo = le.fit_transform(alvo)
    alvo

# %%
# Divide os dados em conjuntos de treino (80%) e teste (20%) de forma aleatória.
x_train, x_test, y_train, y_test = train_test_split(dados, alvo, test_size=0.20, random_state=42)

# Define a arquitetura da rede neural com três camadas densas (fully connected).
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(), # Achata a entrada (transforma dados 2D em 1D).
  tf.keras.layers.Dense(128, activation=tf.nn.relu), # Primeira camada oculta com 128 neurônios e ReLU.
  tf.keras.layers.Dense(64, activation=tf.nn.relu), # Segunda camada oculta com 64 neurônios e ReLU.
  tf.keras.layers.Dense(4, activation=tf.nn.softmax) # Camada de saída com 4 neurônios (para classificação) e Softmax.
])

# Compila o modelo especificando o otimizador, a função de perda e as métricas de avaliação.
model.compile(optimizer= tf.keras.optimizers.Adam(),
              loss='sparse_categorical_crossentropy', # Usada para classificação multiclasse.
              metrics=['Accuracy']) # Avalia a acurácia durante o treinamento.

# Treina o modelo no conjunto de treino por 50 épocas.
model.fit(x_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Accuracy: 0.4217 - loss: 671.8544
# Epoch 2/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.5737 - loss: 22.5657
# Epoch 3/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.7431 - loss: 6.6968
# Epoch 4/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.7241 - loss: 10.3194
# Epoch 5/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8267 - loss: 4.6224
# Epoch 6/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8274 - loss: 4.2806
# Epoch 7/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.7658 - loss: 11.9395
# Epoch 8/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.6763 - loss: 34.8581
# Epoch 9/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8515 - loss: 4.2230
# Epoch 10/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8715 - loss: 4.2111
# Epoch 11/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8009 - loss: 7.8387
# Epoch 12/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.7737 - loss: 11.2234
# Epoch 13/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8688 - loss: 3.9600
# Epoch 14/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.7812 - loss: 11.1208
# Epoch 15/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8685 - loss: 4.8014
# Epoch 16/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.9022 - loss: 3.0566
# Epoch 17/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8314 - loss: 7.1345
# Epoch 18/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8291 - loss: 8.3650
# Epoch 19/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - Accuracy: 0.9043 - loss: 3.6594
# Epoch 20/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8236 - loss: 10.6158
# Epoch 21/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8172 - loss: 10.8225
# Epoch 22/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8948 - loss: 2.3620
# Epoch 23/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8625 - loss: 8.1393
# Epoch 24/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8650 - loss: 5.3511
# Epoch 25/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8982 - loss: 4.5536
# Epoch 26/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8591 - loss: 5.9088
# Epoch 27/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8635 - loss: 7.9013
# Epoch 28/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9147 - loss: 3.1593
# Epoch 29/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8968 - loss: 5.2755
# Epoch 30/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9274 - loss: 3.2579
# Epoch 31/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9255 - loss: 1.9449
# Epoch 32/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8928 - loss: 7.3469
# Epoch 33/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8615 - loss: 6.9755
# Epoch 34/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8162 - loss: 9.6859
# Epoch 35/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - Accuracy: 0.8974 - loss: 5.7087
# Epoch 36/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8883 - loss: 4.7653
# Epoch 37/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9061 - loss: 4.0014
# Epoch 38/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8328 - loss: 11.7256
# Epoch 39/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8408 - loss: 10.7168
# Epoch 40/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9183 - loss: 4.3304
# Epoch 41/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8847 - loss: 4.9451
# Epoch 42/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.8541 - loss: 10.3297
# Epoch 43/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8928 - loss: 5.9070
# Epoch 44/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8794 - loss: 6.6665
# Epoch 45/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9186 - loss: 2.2742
# Epoch 46/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8725 - loss: 7.9033
# Epoch 47/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.8430 - loss: 9.8659
# Epoch 48/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9075 - loss: 5.6905
# Epoch 49/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9184 - loss: 5.5660
# Epoch 50/50
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9249 - loss: 3.7275

# %%
# Avalia o modelo no conjunto de teste e exibe a acurácia.
model.evaluate(x_test, y_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Accuracy: 0.9471 - loss: 1.2779
# [1.313502550125122, 0.9514925479888916]

# %%
# Faz previsões no conjunto de teste.
previsoes_prob = model.predict(x_test)

# Converte as probabilidades previstas em rótulos de classe (o índice do maior valor em cada previsão).
previsoes = np.argmax(previsoes_prob, axis=1)

# Calcula a matriz de confusão comparando os rótulos reais com as previsões feitas pelo modelo.
matrix = confusion_matrix(y_test, previsoes)

# Exibe a matriz de confusão.
print(matrix)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# [[199  13]
#  [  0  56]]
